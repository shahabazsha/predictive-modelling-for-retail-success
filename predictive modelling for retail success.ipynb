# %%
print("retail prediction project started")
# Out:
# retail prediction project started

# %%
import pandas as pd

# %%
data = pd.read_csv("retail_sales.csv")

# %%
data.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
data.shape
# Out:
# (1000, 9)

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
data.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
data.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
import pandas as pd

# %%
data = pd.read_csv("retail_sales.csv")

# %%
data.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
data.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
data = data.dropna()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data = data.drop_duplicates()

# %%
data.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
data["Date"] = pd.to_datetime(data["Date"])

# %%
data.to_csv("clean_retail_sales.csv",index=False)

# %%
import pandas as pd

# %%
data = pd.read_csv("retail_sales.csv")

# %%
import matplotlib.pyplot as plt

# %%
data["Total Amount"].hist()
plt.show()

# %%
data["Age"].hist()
plt.show()

# %%
data["Quantity"].hist()
plt.show()

# %%
data["Price per Unit"].hist()
plt.show()

# %%
import pandas as pd

# %%
data = pd.read_csv("retail_sales.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = data[["Age", "Quantity", "Price per Unit"]]

# %%
Y = data["Total Amount"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
print(predictions[:10])
# Out:
# [1339.95910882   46.08170522  481.77205118  340.32745977 1543.9311768
#   196.71065034 -147.94393475  508.89867301  385.30506588 1160.40100048]

# %%
import pandas as pd

# %%
comparison = pd.DataFrame({
    "Actual": Y_test,
    "Predicted": predictions
})

print(comparison.head())
# Out:
#      Actual    Predicted
# 521    1500  1339.959109
# 737     100    46.081705
# 740     300   481.772051
# 660     100   340.327460
# 411    2000  1543.931177

# %%
mse = mean_squared_error(Y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 41896.2132213436

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(Y_test, predictions)
print("R2 Score:", accuracy)
# Out:
# R2 Score: 0.8568772264250432

# %%
import numpy as np
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 204.68564488342508

# %%
plt.figure()
plt.scatter(Y_test, predictions)

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Sales")

plt.show()
